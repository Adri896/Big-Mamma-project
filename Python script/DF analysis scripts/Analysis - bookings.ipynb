# %% [markdown]
# Analysis of the booking table

# %%
from google.cloud import bigquery
import pandas as pd
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Now you can use the environment variable
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")


# Create a BigQuery client
client = bigquery.Client()

# Your BigQuery query
query = """
SELECT * FROM `big-mamma-project.base_analysis_tables.bookings_analysis`
"""

# Run the query and convert it to a pandas dataframe
bookings = client.query(query,location="EU").to_dataframe()

# Now df is a pandas DataFrame containing the results of the query
bookings
# Out:
#                                                         id  \
# 0        ahNzfnNldmVucm9vbXMtc2VjdXJlciULEhtuaWdodGxvb3...
# 1        ahNzfnNldmVucm9vbXMtc2VjdXJlcigLEhtuaWdodGxvb3...
# 2        ahNzfnNldmVucm9vbXMtc2VjdXJlcigLEhtuaWdodGxvb3...
# 3        ahNzfnNldmVucm9vbXMtc2VjdXJlciULEhtuaWdodGxvb3...
# 4        ahNzfnNldmVucm9vbXMtc2VjdXJlcigLEhtuaWdodGxvb3...
# ...                                                    ...
# 1147033  ahNzfnNldmVucm9vbXMtc2VjdXJlciULEhtuaWdodGxvb3...
# 1147034  ahNzfnNldmVucm9vbXMtc2VjdXJlcigLEhtuaWdodGxvb3...
# 1147035  ahNzfnNldmVucm9vbXMtc2VjdXJlciULEhtuaWdodGxvb3...
# 1147036  ahNzfnNldmVucm9vbXMtc2VjdXJlciULEhtuaWdodGxvb3...
# 1147037  ahNzfnNldmVucm9vbXMtc2VjdXJlciULEhtuaWdodGxvb3...
#
#                             order_id        date  site_id status_simple  \
# 0                               None  2023-06-26       13      Complete
# 1                               None  2023-01-12       12      Complete
# 2                               None  2023-09-30       83      Canceled
# 3                               None  2022-08-03       12      Complete
# 4                               None  2022-12-22       12      Canceled
# ...                              ...         ...      ...           ...
# 1147033                A781468.49451  2023-08-21       81      Complete
# 1147034               A700727.125703  2023-02-01       34      Complete
# 1147035  A781468.56373,A781468.56376  2023-09-20       81      Complete
# 1147036  A781468.62367,A781468.62370  2023-10-13       81      Complete
# 1147037  A781468.65831,A781468.65835  2023-10-26       81      Complete
#
#         shift_category                              venue_group_client_id  \
# 0                  DAY  ahNzfnNldmVucm9vbXMtc2VjdXJlciQLEhpuaWdodGxvb3...
# 1                  DAY  ahNzfnNldmVucm9vbXMtc2VjdXJlcicLEhpuaWdodGxvb3...
# 2               DINNER  ahNzfnNldmVucm9vbXMtc2VjdXJlcicLEhpuaWdodGxvb3...
# 3                  DAY  ahNzfnNldmVucm9vbXMtc2VjdXJlciQLEhpuaWdodGxvb3...
# 4                  DAY  ahNzfnNldmVucm9vbXMtc2VjdXJlcicLEhpuaWdodGxvb3...
# ...                ...                                                ...
# 1147033         DINNER  ahNzfnNldmVucm9vbXMtc2VjdXJlciQLEhpuaWdodGxvb3...
# 1147034         DINNER  ahNzfnNldmVucm9vbXMtc2VjdXJlcicLEhpuaWdodGxvb3...
# 1147035          LUNCH  ahNzfnNldmVucm9vbXMtc2VjdXJlciQLEhpuaWdodGxvb3...
# 1147036         DINNER  ahNzfnNldmVucm9vbXMtc2VjdXJlciQLEhpuaWdodGxvb3...
# 1147037         DINNER  ahNzfnNldmVucm9vbXMtc2VjdXJlciQLEhpuaWdodGxvb3...
#
#          max_guests  duration       booked_by     first_name last_name
# 0                35       270           Staff  Privatisation         N
# 1                 1        15         Walk In           None      None
# 2                 1        15         Walk In          Lunch      None
# 3                 3        15  Booking Widget           Finn         L
# 4                 1        15         Walk In           None      None
# ...             ...       ...             ...            ...       ...
# 1147033           6       210  Booking Widget        Anshika         V
# 1147034           2       210           Staff       Florence         E
# 1147035           9       210  Booking Widget         Andrew         W
# 1147036           9       210  Booking Widget          Hiral         T
# 1147037          12       210  Booking Widget          Doris         C
#
# [1147038 rows x 12 columns]

# %% [markdown]
# ## Bookings stats : origins, status, motivations..

# %% [markdown]
# Channels

# %%
#Booking channel per restaurant 
bookings_origin=bookings.groupby(['site_id','booked_by'],as_index=False)["id"].count()
bookings_origin=bookings_origin.rename(columns={'id':'count','site_id':'restaurant','booked_by':'booking_channel'})

#Creating a dict of total bookings types by restaurant
status ={}
for x in bookings_origin['restaurant'].unique():
    status[x]=bookings_origin.loc[bookings_origin['restaurant'] == x,'count'].sum()

#Function to calculate % of status in total participation for each restaurant 
x = 0
for y in bookings_origin['restaurant']:
        #using loc to append result to each different line of the df
        bookings_origin.loc[x, 'percent'] = round((bookings_origin.loc[x,"count"]/status[y])*100,2)
        x += 1       

bookings_origin.sort_values(by=['restaurant','count'],ascending=False)
# Out:
#     restaurant   booking_channel   count  percent
# 31          83    Booking Widget   27348    64.77
# 36          83           Walk In    5291    12.53
# 35          83            Sunday    4549    10.77
# 32          83            Google    1585     3.75
# 30          83  Bigmamma Website    1439     3.41
# 34          83             Staff    1408     3.33
# 33          83      Landing Page     600     1.42
# 24          81    Booking Widget   71839    69.53
# 29          81           Walk In   11029    10.67
# 28          81            Sunday    9991     9.67
# 27          81             Staff    3718     3.60
# 23          81  Bigmamma Website    3223     3.12
# 25          81            Google    2706     2.62
# 26          81      Landing Page     817     0.79
# 17          34    Booking Widget  254186    72.37
# 22          34           Walk In   66371    18.90
# 20          34             Staff   11754     3.35
# 21          34            Sunday   10186     2.90
# 16          34  Bigmamma Website    4597     1.31
# 18          34            Google    3088     0.88
# 19          34      Landing Page    1070     0.30
# 9           13    Booking Widget  312132    81.35
# 15          13           Walk In   52187    13.60
# 12          13             Staff    5728     1.49
# 13          13            Sunday    5527     1.44
# 10          13            Google    2774     0.72
# 8           13  Bigmamma Website    2346     0.61
# 11          13      Landing Page    1614     0.42
# 14          13      Trip Advisor    1381     0.36
# 1           12    Booking Widget  214667    80.53
# 7           12           Walk In   27096    10.17
# 2           12            Google    9450     3.55
# 4           12             Staff    7806     2.93
# 5           12            Sunday    4196     1.57
# 0           12  Bigmamma Website    1355     0.51
# 6           12      Trip Advisor    1102     0.41
# 3           12      Landing Page     882     0.33

# %% [markdown]
# Status per site

# %%
#Booking status per restaurant 
bookings_status=bookings.groupby(['site_id','status_simple'],as_index=False)["id"].count()
bookings_status=bookings_status.rename(columns={'id':'count','site_id':'restaurant','booked_by':'booking_channel'})

#Creating a dict of total bookings types by restaurant
status ={}
for x in bookings_status['restaurant'].unique():
    status[x]=bookings_status.loc[bookings_status['restaurant'] == x,'count'].sum()

#Function to calculate % of status in total participation for each restaurant 
x = 0
for y in bookings_status['restaurant']:
        #using loc to append result to each different line of the df
        bookings_status.loc[x, 'percent'] = round((bookings_status.loc[x,"count"]/status[y])*100,2)
        x += 1       

bookings_status.sort_values(by=['restaurant','count'],ascending=False)
# Out:
#     restaurant status_simple   count  percent
# 25          83      Complete   28451    67.39
# 24          83      Canceled    8324    19.72
# 26          83    Incomplete    4651    11.02
# 27          83       No Show     794     1.88
# 21          81      Complete   68137    65.95
# 20          81      Canceled   23393    22.64
# 22          81    Incomplete    7684     7.44
# 23          81       No Show    4109     3.98
# 15          34      Complete  236030    67.20
# 14          34      Canceled   84237    23.98
# 18          34       No Show   20695     5.89
# 17          34    Incomplete    9181     2.61
# 13          34        Booked     947     0.27
# 16          34     Confirmed     154     0.04
# 19          34  Wrong Number       8     0.00
# 9           13      Complete  246244    64.18
# 8           13      Canceled  100271    26.13
# 12          13       No Show   22955     5.98
# 11          13    Incomplete   12818     3.34
# 7           13        Booked    1187     0.31
# 10          13     Confirmed     214     0.06
# 2           12      Complete  169740    63.68
# 1           12      Canceled   75690    28.40
# 5           12       No Show   12763     4.79
# 4           12    Incomplete    7259     2.72
# 0           12        Booked     976     0.37
# 3           12     Confirmed     125     0.05
# 6           12  Wrong Number       1     0.00

# %%
bookings_origin.to_csv('bookings_origin.csv',index=False)
bookings_status.to_csv('bookings_status.csv',index=False )
